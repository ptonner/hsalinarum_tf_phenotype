# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import GPy, patsy, pickle, utils, plot, analyze

# %%
data = pd.read_csv("data/tidy_normalize_log_st0.csv",index_col=None)
data = data[(data.heatshock==1)]

skip_strains = ['ura3_EV', u'cspD1_EV', u'cspD1_cspD1','ura3',
                'VNG1179C+pMTFcmyc','VNG1179C-VNG1179C','ura3+pMTFcmyc']

# %%
reload(analyze)

analysis = analyze.Analysis(data,'',2,'heatshock',1,lambda x: x[:,1:],
                           time = np.arange(0,28,2),skip_strains=skip_strains)#,strains=['asnC','copR'])
analysis.run(delta=True,_plot=True)
# Out:
# VNG0039: (1176, 3)
# VNG0194H: (1344, 3)
# VNG0471: (1176, 3)
# VNG1029: (1176, 3)
# VNG2268: (1176, 3)
# VNG2614: (1176, 3)
# arcR: (1176, 3)
# asnC: (1344, 3)
# birA: (1176, 3)
# copR: (1512, 3)
# cspD1: (1344, 3)
# cspD2: (1176, 3)
# hlx1: (1176, 3)
# hlx2: (1176, 3)
# hrg: (1176, 3)
# idr1: (1176, 3)
# idr2: (1344, 3)
# kaiC: (1176, 3)
# phoU: (1344, 3)
# prp2: (1176, 3)
# rosR: (1176, 3)
# sirR: (1176, 3)
# trh2: (1344, 3)
# trh3: (1176, 3)
# trh4: (1176, 3)
# trmB: (1176, 3)
# troR: (1176, 3)

# %%
reload(plot)
plt.figure(figsize=(24,.5*27))
plot.plot_delta(analysis.full_time,analysis.od_delta,mean=False,probability=True,cluster=True,plot_cluster=True)

# %%
plt.figure(figsize=(24,.5*27))
plot.plot_delta(analysis.full_time,analysis.od_delta_deriv,mean=False,probability=True,cluster=True,plot_cluster=True,
                cluster_kwargs={"method":'complete'},ytick_filter=lambda x: "$\Delta %s$"%x)
# Out:
#  plot.py:54: VisibleDeprecationWarning:using a non-integer number instead of an integer will result in an error in the future

# %%
analysis.plot_deltas()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-15-e27320b1f459> in <module>()
# ----> 1 analysis.plot_deltas()
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/analyze.pyc in plot_deltas(self)
#     215         def plot_deltas(self):
#     216                 plt.figure(figsize=(24,.5*len(self._strains)))
# --> 217                 plot.plot_delta(self.full_time,self.od_delta_deriv,mean=False,probability=True,cluster=True,plot_cluster=True,cluster_kwargs={"method":'complete'},ytick_filter=lambda x: "$\Delta %s$"%x)
#     218                 plt.yticks(fontsize=15)
#     219                 plt.savefig("figures/%s/od_delta_deriv_prob.png"%self.label,bbox_inches="tight")
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/plot.pyc in plot_delta(x, deltas, mean, probability, cluster, plot_cluster, cluster_kwargs, ytick_filter)
#      34         if plot_cluster:
#      35             ax = plt.subplot2grid((1,6),(0,0),colspan=1,rowspan=1)
# ---> 36             dendrogram(l,no_labels=True,orientation='left',ax=ax)
#      37
#      38     if mean:
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/scipy/cluster/hierarchy.pyc in dendrogram(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, no_plot, no_labels, leaf_font_size, leaf_rotation, leaf_label_func, show_contracted, link_color_func, ax, above_threshold_color)
#    2302                          contraction_marks=contraction_marks,
#    2303                          ax=ax,
# -> 2304                          above_threshold_color=above_threshold_color)
#    2305
#    2306     return R
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/scipy/cluster/hierarchy.pyc in _plot_dendrogram(icoords, dcoords, ivl, p, n, mh, orientation, no_labels, color_list, leaf_font_size, leaf_rotation, contraction_marks, ax, above_threshold_color)
#    1874     for color in colors_used:
#    1875         if color != above_threshold_color:
# -> 1876             ax.add_collection(colors_to_collections[color])
#    1877     # If there's a grouping of links above the color threshold, it goes last.
#    1878     if above_threshold_color in colors_to_collections:
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in add_collection(self, collection, autolim)
#    1677
#    1678         if autolim:
# -> 1679             self.update_datalim(collection.get_datalim(self.transData))
#    1680
#    1681         collection._remove_method = lambda h: self.collections.remove(h)
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/matplotlib/collections.pyc in get_datalim(self, transData)
#     204                 transform.frozen(), paths, self.get_transforms(),
#     205                 offsets, transOffset.frozen())
# --> 206             result = result.inverse_transformed(transData)
#     207         else:
#     208             result = transforms.Bbox.null()
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverse_transformed(self, transform)
#     531         the inverse of the given transform.
#     532         """
# --> 533         return self.transformed(transform.inverted())
#     534
#     535     coefs = {'C':  (0.5, 0.5),
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2377
#    2378     def inverted(self):
# -> 2379         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2380     inverted.__doc__ = Transform.inverted.__doc__
#    2381
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    2377
#    2378     def inverted(self):
# -> 2379         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2380     inverted.__doc__ = Transform.inverted.__doc__
#    2381
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/matplotlib/transforms.pyc in inverted(self)
#    1773             if self._shorthand_name:
#    1774                 shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1775             self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1776             self._invalid = 0
#    1777         return self._inverted
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     524     signature = 'D->D' if isComplexType(t) else 'd->d'
#     525     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 526     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     527     return wrap(ainv.astype(result_t, copy=False))
#     528
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     337                 pass
#     338             else:
# --> 339                 return printer(obj)
#     340             # Finally look for special method names
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     226
#     227     if 'png' in formats:
# --> 228         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     229     if 'retina' in formats or 'png2x' in formats:
#     230         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     117
#     118     bytes_io = BytesIO()
# --> 119     fig.canvas.print_figure(bytes_io, **kw)
#     120     data = bytes_io.getvalue()
#     121     if fmt == 'svg':
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2178                     orientation=orientation,
#    2179                     dryrun=True,
# -> 2180                     **kwargs)
#    2181                 renderer = self.figure._cachedRenderer
#    2182                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /home/ptonner/dev/hsalinarum_tf_phenotype/local/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     535             close = False
#     536         try:
# --> 537             _png.write_png(renderer._renderer, filename_or_obj, self.figure.dpi)
#     538         finally:
#     539             if close:
#
# RuntimeError: libpng signaled error
